# %% [markdown]
# <a href="https://colab.research.google.com/github/Chicaeme/Geopandas-Fontibon-map/blob/main/MapitaFontibon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import json

# %%
datosDF= gpd.read_file("barrios.json")

datosDF
# Out:
#       objectid  cod_loc     localidad         estado               barriocomu  \
# 0          629        9      Fontibón  SIN LEGALIZAR                  Batavia
# 1          639        1       Usaquén  SIN LEGALIZAR                  Belmira
# 2          640        1       Usaquén     LEGALIZADO              Las_Acacias
# 3          660       18  Rafael Uribe     LEGALIZADO  Carmen del Sol I Sector
# 4          665        1       Usaquén  SIN LEGALIZAR            Urb. Furatena
# ...        ...      ...           ...            ...                      ...
# 3866       468        5          Usme     LEGALIZADO             Villa Rosita
# 3867       472        5          Usme     LEGALIZADO       Tocaimita Oriental
# 3868       475        5          Usme  SIN LEGALIZAR         S.C. Tibaque Sur
# 3869       478        5          Usme     LEGALIZADO                Chico Sur
# 3870       485       11          None  SIN LEGALIZAR     Ciudadela El Poblado
#
# ...

# %%
datosDF.to_crs(epsg=9377, inplace=True)

datosDF
# Out:
#       objectid  cod_loc     localidad         estado               barriocomu  \
# 0          629        9      Fontibón  SIN LEGALIZAR                  Batavia
# 1          639        1       Usaquén  SIN LEGALIZAR                  Belmira
# 2          640        1       Usaquén     LEGALIZADO              Las_Acacias
# 3          660       18  Rafael Uribe     LEGALIZADO  Carmen del Sol I Sector
# 4          665        1       Usaquén  SIN LEGALIZAR            Urb. Furatena
# ...        ...      ...           ...            ...                      ...
# 3866       468        5          Usme     LEGALIZADO             Villa Rosita
# 3867       472        5          Usme     LEGALIZADO       Tocaimita Oriental
# 3868       475        5          Usme  SIN LEGALIZAR         S.C. Tibaque Sur
# 3869       478        5          Usme     LEGALIZADO                Chico Sur
# 3870       485       11          None  SIN LEGALIZAR     Ciudadela El Poblado
#
# ...

# %%
FontibonFiltrado= datosDF[datosDF["cod_loc"]==9]

FontibonFiltrado
# Out:
#       objectid  cod_loc localidad         estado               barriocomu  \
# 0          629        9  Fontibón  SIN LEGALIZAR                  Batavia
# 27         962        9  Fontibón  SIN LEGALIZAR  Bellavista Los Pantanos
# 141        507        9  Fontibón  SIN LEGALIZAR             Urb. Batavia
# 194        504        9  Fontibón  SIN LEGALIZAR             Santiago III
# 195        514        9  Fontibón  SIN LEGALIZAR       Veracruz II Sector
# ...        ...      ...       ...            ...                      ...
# 3758        30        9  Fontibón  SIN LEGALIZAR        Flota La Macarena
# 3766        89        9  Fontibón     LEGALIZADO        Bosque de Modelia
# 3778       193        9  Fontibón  SIN LEGALIZAR          S.C. El Pantano
# 3779       212        9  Fontibón  SIN LEGALIZAR           Urb. Corpacero
# 3785       258        9  Fontibón  SIN LEGALIZAR          Urb. La Dulzura
#
#       cod_polbar    shape_area  shape_len geo_shape  \
# ...

# %%
mapa= FontibonFiltrado.plot(
    column= "barriocomu",
    figsize=(80,30),
    edgecolor="black",

    )

# %%
mapa= FontibonFiltrado.plot(
    column= "barriocomu",
    figsize=(30,30),
    edgecolor="black",
    legend= True,
  legend_kwds= {
      'loc': "upper left"
  }


    )
